# %%
from box import ConfigBox



a = {'key1': 'value1', 'key2': 'value2'}
b= ConfigBox(a)

b.key1
# Out:
# 'value1'

# %%
from ensure import ensure_annotations

@ensure_annotations
def test(a: int, b: int) -> int:
    return a + b

test(1, 2)
# Out:
# 3

# %%
test("5", 2)
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 test("5", 2)
#
# File a:\Future\MLOPS\Projects\Data science pro\.venv\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument a of type <class 'str'> to <function test at 0x00000205C756B560> does not match annotation type <class 'int'>
